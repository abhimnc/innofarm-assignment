# %% [markdown]
# **Install required libraries**

# %%
# !pip install Pillow
# !pip install opencv-python scikit-learn mahotas numpy tqdm
# !pip install pillow torchvision tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# **Import dataset from Kaggle**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ashishjstar/lettuce-diseases")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/lettuce-diseases

# %% [markdown]
# **check Folder contents**

# %%
import os
dir = path + "/Lettuce_disease_datasets"

# List all folders in the directory
sub_folders = [name for name in os.listdir(dir)
           if os.path.isdir(os.path.join(dir, name))]

print("Folders found:")
for folder in sub_folders:
    print(folder)
# Out:
# Folders found:
# Wilt_and_leaf_blight_on_lettuce
# Bacterial
# Downy_mildew_on_lettuce
# Shepherd_purse_weeds
# Viral
# Healthy
# Septoria_blight_on_lettuce
# Powdery_mildew_on_lettuce

# %% [markdown]
# **To check file content inside folder**

# %%
import os

# Path to the parent directory
parent_dir = dir

# Loop through each item in the parent directory
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    # Check if it is a folder
    if os.path.isdir(folder_path):
        print(f"\nFiles in folder: {folder_name}")

        # Loop through each file in the folder
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if os.path.isfile(file_path):
                print(f"  - {file_name}")
# Out:
# Files in folder: Wilt_and_leaf_blight_on_lettuce
#   - wlbl (5).jpg
#   - wlbl (1).jpg
#   - wlbl (2).jpg
#   - wlbl (3).jpg
#   - wlbl (4).jpg
#   - wlbl (6).jpg
#
# Files in folder: Bacterial
#   - bct (16).jpg
#   - bct (20).jpg
#   - bct (13).jpg
#   - bct (17).jpg
#   - bct (5).jpg
#   - bct (19).jpg
#   - bct (7).jpg
#   - bct (18).jpg
#   - bct (4).jpg
#   - bct (12).jpg
#   - bct (15).jpg
#   - bct (8).jpg
#   - bct (11).jpg
#   - bct (9).jpg
#   - bct (3).jpg
#   - bct (2).jpg
#   - bct (10).jpg
#   - bct (6).jpg
#   - bct (1).jpg
#   - bct (14).jpg
#
# Files in folder: Downy_mildew_on_lettuce
#   - dml (11).jpg
#   - dml (12).jpg
#   - dml (5).jpg
#   - dml (4).jpg
#   - dml (1).jpg
#   - dml (28).jpg
#   - dml (10).jpg
#   - dml (27).jpg
#   - dml (3).jpg
#   - dml (22).jpg
#   - dml (7).jpg
#   - dml (19).jpg
#   - dml (13).jpg
#   - dml (9).jpg
#   - dml (14).jpg
#   - dml (8).jpg
#   - dml (20).jpg
#   - dml (21).jpg
#   - dml (29).jpg
#   - dml (2).jpg
# ...

# %% [markdown]
# **Files number in each file.**

# %%
import os

# Path to the parent directory
parent_dir = dir

# Loop through each folder
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    if os.path.isdir(folder_path):
        # Count only files
        num_files = sum(
            1 for file in os.listdir(folder_path)
            if os.path.isfile(os.path.join(folder_path, file))
        )
        print(f"{folder_name}: {num_files} file(s)")
# Out:
# Wilt_and_leaf_blight_on_lettuce: 6 file(s)
# Bacterial: 20 file(s)
# Downy_mildew_on_lettuce: 30 file(s)
# Shepherd_purse_weeds: 1106 file(s)
# Viral: 15 file(s)
# Healthy: 1123 file(s)
# Septoria_blight_on_lettuce: 19 file(s)
# Powdery_mildew_on_lettuce: 18 file(s)

# %% [markdown]
# **Dataset Description**
#
# ```
# Septoria_blight_on_lettuce: 19 file(s)
# Powdery_mildew_on_lettuce: 18 file(s)
# Wilt_and_leaf_blight_on_lettuce: 6 file(s)
# Viral: 15 file(s)
# Shepherd_purse_weeds: 1106 file(s)
# Healthy: 1123 file(s)
# Downy_mildew_on_lettuce: 30 file(s)
# Bacterial: 20 file(s)
# ```

# %% [markdown]
# **checking image details - dimension, memory size**

# %%
import os
from PIL import Image

# Path to the parent directory
parent_dir = dir

# Loop through each folder
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    if os.path.isdir(folder_path):
        print(f"\nFolder: {folder_name}")

        # Loop through each image file in the folder
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)

            if os.path.isfile(file_path):
                try:
                    with Image.open(file_path) as img:
                        width, height = img.size
                    file_size_kb = os.path.getsize(file_path) / 1024  # size in KB
                    print(f"  {file_name}: {width}x{height}px, {file_size_kb:.2f} KB")
                except Exception as e:
                    print(f"  {file_name}: Error reading image - {e}")
# Out:
# Folder: Shepherd_purse_weeds
#   spw (323).jpg: 126x162px, 7.99 KB
#   spw (480).jpg: 103x128px, 7.10 KB
#   spw (587).jpg: 37x93px, 1.95 KB
#   spw (495).jpg: 140x140px, 9.86 KB
#   spw (440).jpg: 425x279px, 37.94 KB
#   spw (530).jpg: 273x220px, 20.84 KB
#   spw (454).jpg: 272x404px, 35.20 KB
#   spw (1068).jpg: 416x1010px, 125.57 KB
#   spw (815).jpg: 351x283px, 34.43 KB
#   spw (225).jpg: 1038x1038px, 175.37 KB
#   spw (210).jpg: 286x286px, 15.13 KB
#   spw (700).jpg: 305x161px, 16.28 KB
#   spw (680).jpg: 68x127px, 3.10 KB
#   spw (834).jpg: 556x835px, 132.07 KB
#   spw (975).jpg: 137x137px, 6.57 KB
#   spw (9).jpg: 149x149px, 4.60 KB
#   spw (787).jpg: 183x246px, 15.64 KB
#   spw (775).jpg: 323x239px, 26.13 KB
#   spw (1051).jpg: 463x350px, 38.85 KB
#   spw (5).jpg: 101x101px, 2.40 KB
#   spw (311).jpg: 160x147px, 9.30 KB
#   spw (10).jpg: 149x149px, 4.37 KB
#   spw (846).jpg: 119x162px, 6.30 KB
#   spw (909).jpg: 257x233px, 18.29 KB
#   spw (657).jpg: 192x218px, 12.98 KB
# ...

# %%
import os
from PIL import Image

# Path to the parent directory
parent_dir = dir

# Loop through each folder
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    if os.path.isdir(folder_path):
        print(f"\nFolder: {folder_name}")

        # Loop through each image file in the folder
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)

            if os.path.isfile(file_path):
                try:
                    with Image.open(file_path) as img:
                        width, height = img.size
                    file_size_kb = os.path.getsize(file_path) / 1024  # size in KB
                    print(f"  {file_name}: {width}x{height}px, {file_size_kb:.2f} KB")
                except Exception as e:
                    print(f"  {file_name}: Error reading image - {e}")
# Out:
# Folder: Shepherd_purse_weeds
#   spw (323).jpg: 126x162px, 7.99 KB
#   spw (480).jpg: 103x128px, 7.10 KB
#   spw (587).jpg: 37x93px, 1.95 KB
#   spw (495).jpg: 140x140px, 9.86 KB
#   spw (440).jpg: 425x279px, 37.94 KB
#   spw (530).jpg: 273x220px, 20.84 KB
#   spw (454).jpg: 272x404px, 35.20 KB
#   spw (1068).jpg: 416x1010px, 125.57 KB
#   spw (815).jpg: 351x283px, 34.43 KB
#   spw (225).jpg: 1038x1038px, 175.37 KB
#   spw (210).jpg: 286x286px, 15.13 KB
#   spw (700).jpg: 305x161px, 16.28 KB
#   spw (680).jpg: 68x127px, 3.10 KB
#   spw (834).jpg: 556x835px, 132.07 KB
#   spw (975).jpg: 137x137px, 6.57 KB
#   spw (9).jpg: 149x149px, 4.60 KB
#   spw (787).jpg: 183x246px, 15.64 KB
#   spw (775).jpg: 323x239px, 26.13 KB
#   spw (1051).jpg: 463x350px, 38.85 KB
#   spw (5).jpg: 101x101px, 2.40 KB
#   spw (311).jpg: 160x147px, 9.30 KB
#   spw (10).jpg: 149x149px, 4.37 KB
#   spw (846).jpg: 119x162px, 6.30 KB
#   spw (909).jpg: 257x233px, 18.29 KB
#   spw (657).jpg: 192x218px, 12.98 KB
# ...

# %% [markdown]
# ` Resizing the image to 224*224 for processing. Ignoring those which have dimension less than 100*100`

# %%
import os
from PIL import Image
from torchvision import transforms
import torch
from tqdm import tqdm

# 🔧 CONFIG
DATASET_DIR = dir
SAVE_PROCESSED_IMAGES = True          # Set to True if you want to save resized images
OUTPUT_DIR = '/content/processed' # Only used if SAVE_PROCESSED_IMAGES is True
MIN_WIDTH = 100
MIN_HEIGHT = 100

# 💡 Define preprocessing pipeline
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),  # Converts to CxHxW, range [0,1]
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # ImageNet stats
                         std=[0.229, 0.224, 0.225])
])
if SAVE_PROCESSED_IMAGES:
    os.makedirs(OUTPUT_DIR, exist_ok=True)
# 📦 Process images folder-by-folder
for class_folder in os.listdir(DATASET_DIR):
    class_path = os.path.join(DATASET_DIR, class_folder)
    if not os.path.isdir(class_path):
        continue

    print(f"\n📂 Processing folder: {class_folder}")

    # Create output folder if saving
    if SAVE_PROCESSED_IMAGES:
        os.makedirs(os.path.join(OUTPUT_DIR, class_folder), exist_ok=True)

    for file_name in tqdm(os.listdir(class_path)):
        file_path = os.path.join(class_path, file_name)

        try:
            with Image.open(file_path) as img:
                img = img.convert('RGB')  # Ensure 3 channels
                width, height = img.size

                # Filter too-small images
                if width < MIN_WIDTH or height < MIN_HEIGHT:
                    print(f"⚠️ Skipped (too small): {file_name} ({width}x{height})")
                    continue

                # Apply preprocessing
                processed_img = transform(img)

                # Save processed image (optional)
                if SAVE_PROCESSED_IMAGES:
                    save_path = os.path.join(OUTPUT_DIR, class_folder, file_name)
                    img_resized = transforms.Resize((224, 224))(img)
                    img_resized.save(save_path)

        except Exception as e:
            print(f"❌ Failed to process {file_name}: {e}")
# Out:
# 📂 Processing folder: Wilt_and_leaf_blight_on_lettuce
# 100%|██████████| 6/6 [00:00<00:00, 26.47it/s]
# 📂 Processing folder: Bacterial
# 100%|██████████| 20/20 [00:00<00:00, 49.08it/s]
# 📂 Processing folder: Downy_mildew_on_lettuce
# 100%|██████████| 30/30 [00:00<00:00, 31.37it/s]
# 📂 Processing folder: Shepherd_purse_weeds
#   1%|          | 7/1106 [00:00<00:15, 68.81it/s]
# ⚠️ Skipped (too small): spw (1089).jpg (77x87)
# ⚠️ Skipped (too small): spw (99).jpg (80x80)
# ⚠️ Skipped (too small): spw (96).jpg (63x63)
# ⚠️ Skipped (too small): spw (1062).jpg (86x44)
#   4%|▎         | 40/1106 [00:00<00:19, 55.62it/s]
# ⚠️ Skipped (too small): spw (630).jpg (99x185)
# ⚠️ Skipped (too small): spw (231).jpg (76x76)
# ⚠️ Skipped (too small): spw (615).jpg (77x149)
#   5%|▌         | 58/1106 [00:01<00:19, 54.56it/s]
# ⚠️ Skipped (too small): spw (765).jpg (98x143)
#   6%|▋         | 70/1106 [00:01<00:19, 53.44it/s]
# ⚠️ Skipped (too small): spw (587).jpg (37x93)
# ...

# %% [markdown]
# **Resolving undersampling issue**

# %%
import os
from PIL import Image, ImageEnhance, ImageOps, ImageFilter
import random

# output_dir = "processed"
# # Create the directory if it doesn't exist
# os.makedirs(output_dir, exist_ok=True)

# ✅ Replace with your dataset path
parent_dir = "/content/processed/"

# ✅ Folders to augment
folders_to_augment = [
    "Bacterial",
    "Wilt_and_leaf_blight_on_lettuce",
    "Powdery_mildew_on_lettuce",
    "Septoria_blight_on_lettuce",
    "Viral",
    "Downy_mildew_on_lettuce"
]

# 🔁 Number of augmentations per image
AUGMENT_COUNT = 20

# 🔧 Augmentation function
def augment_image(img):
    aug_img = img.copy()

    # Random horizontal flip
    if random.random() > 0.5:
        aug_img = ImageOps.mirror(aug_img)

    # Random rotation
    angle = random.uniform(-20, 20)
    aug_img = aug_img.rotate(angle)

    # Random brightness
    enhancer = ImageEnhance.Brightness(aug_img)
    brightness_factor = random.uniform(0.8, 1.2)
    aug_img = enhancer.enhance(brightness_factor)

    # Optional slight blur
    if random.random() > 0.7:
        aug_img = aug_img.filter(ImageFilter.GaussianBlur(radius=1))

    return aug_img

# 🚀 Process each selected folder
for folder_name in os.listdir(parent_dir):
    if folder_name not in folders_to_augment:
        continue  # skip folders not listed

    folder_path = os.path.join(parent_dir, folder_name)
    if not os.path.isdir(folder_path):
        continue

    print(f"\n📁 Processing folder: {folder_name}")

    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        if os.path.isfile(file_path):
            try:
                with Image.open(file_path) as img:
                    width, height = img.size
                    file_size_kb = os.path.getsize(file_path) / 1024
                    print(f"  📷 {file_name}: {width}x{height}px, {file_size_kb:.2f} KB")

                    for i in range(AUGMENT_COUNT):
                        aug_img = augment_image(img)
                        base_name, ext = os.path.splitext(file_name)
                        aug_filename = f"{base_name}_aug{i+1}{ext}"
                        aug_path = os.path.join(folder_path, aug_filename)
                        aug_img.save(aug_path)
                        print(f"    ➕ Saved: {aug_filename}")

            except Exception as e:
                print(f"  ⚠️ Error with {file_name}: {e}")
# Out:
# 📁 Processing folder: Viral
#   📷 vrl (10).jpg: 224x224px, 7.88 KB
#     ➕ Saved: vrl (10)_aug1.jpg
#     ➕ Saved: vrl (10)_aug2.jpg
#     ➕ Saved: vrl (10)_aug3.jpg
#     ➕ Saved: vrl (10)_aug4.jpg
#     ➕ Saved: vrl (10)_aug5.jpg
#     ➕ Saved: vrl (10)_aug6.jpg
#     ➕ Saved: vrl (10)_aug7.jpg
#     ➕ Saved: vrl (10)_aug8.jpg
#     ➕ Saved: vrl (10)_aug9.jpg
#     ➕ Saved: vrl (10)_aug10.jpg
#     ➕ Saved: vrl (10)_aug11.jpg
#     ➕ Saved: vrl (10)_aug12.jpg
#     ➕ Saved: vrl (10)_aug13.jpg
#     ➕ Saved: vrl (10)_aug14.jpg
#     ➕ Saved: vrl (10)_aug15.jpg
#     ➕ Saved: vrl (10)_aug16.jpg
#     ➕ Saved: vrl (10)_aug17.jpg
#     ➕ Saved: vrl (10)_aug18.jpg
#     ➕ Saved: vrl (10)_aug19.jpg
#     ➕ Saved: vrl (10)_aug20.jpg
#   📷 vrl (1).jpg: 224x224px, 11.26 KB
#     ➕ Saved: vrl (1)_aug1.jpg
#     ➕ Saved: vrl (1)_aug2.jpg
#     ➕ Saved: vrl (1)_aug3.jpg
#     ➕ Saved: vrl (1)_aug4.jpg
#     ➕ Saved: vrl (1)_aug5.jpg
#     ➕ Saved: vrl (1)_aug6.jpg
# ...

# %% [markdown]
# Walks through your dataset folder.
#
# Filters out images smaller than 100×100 px.
#
# Applies preprocessing: resize → normalize → convert to tensor.
#
# saves resized images
#
# Logs skipped or invalid images.

# %%
# Out:
# 🔍 Extracting features...
# ...
# Bacterial: 100%|██████████| 420/420 [00:11<00:00, 35.31it/s]
# 🧠 Training model...

# %%
import os
import cv2
import numpy as np
import mahotas
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

# === CONFIG ===
DATASET_DIR = '/content/processed/'
USE_RANDOM_FOREST = True  # If False, uses SVM
CONFUSION_MATRIX = True
CROSS_VALIDATION = True
FEATURE_IMPORTANCE = True if USE_RANDOM_FOREST else False

# === Feature Extraction Function ===
def extract_features(image_path):
    try:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (128, 128))
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Color histogram (RGB)
        hist = []
        for i in range(3):
            channel_hist = cv2.calcHist([image], [i], None, [32], [0, 256])
            hist.extend(channel_hist.flatten())

        # Haralick texture features
        haralick = mahotas.features.haralick(gray).mean(axis=0)

        return np.hstack([hist, haralick])
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return None

# === Load Dataset ===
print("🔍 Extracting features...")
features, labels = [], []

for class_name in os.listdir(DATASET_DIR):
    class_path = os.path.join(DATASET_DIR, class_name)
    if not os.path.isdir(class_path):
        continue

    for img_name in tqdm(os.listdir(class_path), desc=class_name):
        img_path = os.path.join(class_path, img_name)
        feat = extract_features(img_path)
        if feat is not None:
            features.append(feat)
            labels.append(class_name)

X = np.array(features)
y = np.array(labels)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# === Train/Test Split ===
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, stratify=y, random_state=42
)

# === Model Selection ===
if USE_RANDOM_FOREST:
    model = RandomForestClassifier(n_estimators=100, random_state=42)
else:
    model = SVC(kernel='linear', probability=True)

# === Training ===
print("🧠 Training model...")
model.fit(X_train, y_train)

# === Evaluation ===
y_pred = model.predict(X_test)

print("\n📊 Classification Report:")
print(classification_report(y_test, y_pred))
print("✅ Accuracy:", accuracy_score(y_test, y_pred))

# === Confusion Matrix ===
if CONFUSION_MATRIX:
    cm = confusion_matrix(y_test, y_pred, labels=np.unique(y))
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=np.unique(y), yticklabels=np.unique(y), cmap='Blues')
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

# === Cross-validation ===
if CROSS_VALIDATION:
    print("🔁 Running 5-fold Cross-Validation...")
    scores = cross_val_score(model, X_scaled, y, cv=5)
    print(f"Cross-validation Accuracy: {scores.mean():.4f} ± {scores.std():.4f}")

# === Feature Importance ===
if FEATURE_IMPORTANCE:
    importances = model.feature_importances_
    indices = np.argsort(importances)[-20:][::-1]  # Top 20 features

    plt.figure(figsize=(10, 6))
    plt.title("Top 20 Feature Importances (Random Forest)")
    plt.bar(range(len(indices)), importances[indices], align="center")
    plt.xticks(range(len(indices)), [f"F{i}" for i in indices], rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# 🔍 Extracting features...
# ...
# Bacterial: 100%|██████████| 420/420 [00:10<00:00, 38.65it/s]
# 🧠 Training model...
#
# 📊 Classification Report:
#                                  precision    recall  f1-score   support
#
#                       Bacterial       0.95      0.88      0.91        84
#         Downy_mildew_on_lettuce       0.89      0.96      0.92       126
#                         Healthy       0.97      0.99      0.98       225
#       Powdery_mildew_on_lettuce       0.96      0.93      0.95        75
#      Septoria_blight_on_lettuce       0.92      0.95      0.93        80
#            Shepherd_purse_weeds       0.99      0.99      0.99       195
#                           Viral       0.95      0.87      0.91        63
# Wilt_and_leaf_blight_on_lettuce       1.00      0.80      0.89        25
#
#                        accuracy                           0.95       873
#                       macro avg       0.95      0.92      0.94       873
# ...

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm import tqdm

# --- CONFIG ---
DATA_DIR = '/content/processed/'
USE_PRETRAINED = True
NUM_EPOCHS = 6
BATCH_SIZE = 32
NUM_CLASSES = len(os.listdir(DATA_DIR))
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
IMG_SIZE = 224  # For pretrained models

# --- Transforms ---
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # ImageNet stats
                         std=[0.229, 0.224, 0.225])
])

# --- Dataset and Split ---
full_dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
class_names = full_dataset.classes
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# --- Model ---
if USE_PRETRAINED:
    model = models.resnet18(weights="IMAGENET1K_V1")
    model.fc = nn.Linear(model.fc.in_features, NUM_CLASSES)
else:
    class SimpleCNN(nn.Module):
        def __init__(self, num_classes):
            super().__init__()
            self.net = nn.Sequential(
                nn.Conv2d(3, 32, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
                nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
                nn.Flatten(),
                nn.Linear(64 * (IMG_SIZE//4)**2, 128), nn.ReLU(),
                nn.Linear(128, num_classes)
            )

        def forward(self, x):
            return self.net(x)

    model = SimpleCNN(NUM_CLASSES)

model = model.to(DEVICE)

# --- Loss & Optimizer ---
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# --- Training Loop ---
train_loss_history, val_loss_history = [], []

for epoch in range(NUM_EPOCHS):
    model.train()
    running_loss = 0.0
    for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}"):
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    train_loss_history.append(avg_train_loss)

    # --- Validation ---
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_loss_history.append(avg_val_loss)
    val_accuracy = correct / total

    print(f"Epoch {epoch+1}: Train Loss={avg_train_loss:.4f} | Val Loss={avg_val_loss:.4f} | Val Acc={val_accuracy:.4f}")

# --- Plot Accuracy & Loss ---
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss_history, label='Train Loss')
plt.plot(val_loss_history, label='Val Loss')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
acc_per_epoch = [1 - l for l in val_loss_history]  # (not actual acc, for rough plot)
plt.plot(acc_per_epoch, label='Val Acc (approx)')
plt.title("Accuracy (approximate)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# --- Confusion Matrix ---
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# --- Classification Report ---
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
# Epoch 1/6: 100%|██████████| 110/110 [15:25<00:00,  8.41s/it]
# Epoch 1: Train Loss=0.5436 | Val Loss=1.2169 | Val Acc=0.7468
# Epoch 2/6: 100%|██████████| 110/110 [15:07<00:00,  8.25s/it]
# Epoch 2: Train Loss=0.2504 | Val Loss=0.1959 | Val Acc=0.9267
# Epoch 3/6: 100%|██████████| 110/110 [15:00<00:00,  8.19s/it]
# Epoch 3: Train Loss=0.1685 | Val Loss=0.2757 | Val Acc=0.9198
# Epoch 4/6: 100%|██████████| 110/110 [14:56<00:00,  8.15s/it]
# Epoch 4: Train Loss=0.1748 | Val Loss=0.0733 | Val Acc=0.9656
# Epoch 5/6: 100%|██████████| 110/110 [15:00<00:00,  8.19s/it]
# Epoch 5: Train Loss=0.0636 | Val Loss=0.1279 | Val Acc=0.9553
# Epoch 6/6: 100%|██████████| 110/110 [15:03<00:00,  8.21s/it]
# Epoch 6: Train Loss=0.0783 | Val Loss=0.0672 | Val Acc=0.9759
# Classification Report:
#                                  precision    recall  f1-score   support
#
#                       Bacterial       0.95      0.97      0.96        73
# ...
